# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ## Notebook 1
# This is the content of Notebook 1.

# %% [markdown]
# Here i will show you how to use Jupyter Notebook.
# ## Notebook 2
# This is the content of Notebook 2.
# Here i will show you how to use Python.
# ## Notebook 3
# This is the content of Notebook 3.
# Here i will show you how to use Data Science libraries.
# ## Notebook 4
# This is the content of Notebook 4.
# Here i will show you how to use Machine Learning libraries.
# ## Notebook 5
# This is the content of Notebook 5.
# Here i will show you how to use Deep Learning libraries.

# %% [markdown]
# <p style="color:red; font-size:40px;">Hello World</p>
